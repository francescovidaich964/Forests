# %% [markdown]
# # 1 - Data acquisition

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("bci05.csv")
data.head()
# Out:
#       tag      sp     gx     gy    dbh  pom    date codes status
# 0  105951  ACACME  610.0  104.7  119.0    1  8924.0     M      A
# 1  132160  ACACME  534.8  241.3  116.0    1  8922.0     *      A
# 2  132234  ACACME  539.4  242.3    NaN    0  8922.0    DN      D
# 3  132235  ACACME  538.8  242.5    NaN    0  8922.0    DN      D
# 4  191542  ACACME  282.7  177.5   75.0    1  8825.0     *      A

# %%
data = data[data["status"]=='A'][["tag", "sp", "gx", "gy"]]

# %%
# 1) Species spotting
types = data['sp'].value_counts().keys() 
S = len(types)
print("There are {} different species".format(S))
# Out:
# There are 299 different species

# %% [markdown]
# # 2 - Statistics on subplots
#
# Now we divide the total area of study (sampled plot) in 200 subplots of the same area.
# To do so we add two columns to the dataset, called $i$ and $j$, that are the result of division without rest respectively of $gx$ and $gy$ for 50 (0.5 hectars in each axis). Then we use some methods of pandas to encode in a 3D matrix the aboundance $x_k$ of each of the S species for each subplot $(i,j)$ and from that we can obtain the average presence of each species.

# %%
# 2) Subsampling
# 50 * 50 meters
data["i"], data["j"] = data["gx"]//50, data["gy"]//50
# a)
cell_pop = data.groupby(["i", "j"])["sp"].value_counts()
# b) shaping them in a matrix
cell_pop_M = cell_pop.unstack().stack(dropna = False).fillna(0).astype(int)
cell_pop_M = np.array(cell_pop_M).reshape(20, 10, 299) # (i, j, specie)


# this prints are just for understanding how to work with this dataset
#print("Presence and aboundance in subplot (0,0) : \n", cell_pop_M[0,0,:], '\n')
#print("Aboundances of the various species: \n", cell_pop_M.sum(axis=(0,1)), '\n')

p_i = np.count_nonzero(cell_pop_M, axis = (0,1))/200
#print("Absolute presence for each species: \n", presence, '\n')
#print("Relative presence for each species: \n", p_i, '\n')

# %% [markdown]
# And the average squared difference between present and absent species in a subplot (that will be used as a constraint in section 4):

# %%
def pairing_p(configs):
    # In each subplot there are more absent species than present (just an observation)
    # S+ - S-
    S_present = np.count_nonzero(configs, axis = (1)).flatten()
    # S_absent = S - S_present -> S_pm = 2*S_present - S
    S_pm = 2*S_present - S # Broadcasting
    # constraint C_0 = < (S+ - S-)^2 >
    return np.mean(np.power(S_pm,2))


C_0_over_S = pairing_p(cell_pop_M.reshape(200, 299))/299
print(C_0_over_S)
# Out:
# 21.32829431438127

# %% [markdown]
# ## 3 - Max Ent 1
#
# ### Hamiltonian of the system for our constraints.
#
# We start considering a generic entropy:
#
# $$ S[\{p_a\}_{i=1,\ldots,n}] = -K \sum_{a=1}^n p_a ln(p_a), K > 0$$
#
# and following constraints:
#
# $$ \sum_{a=1}^n p_a - 1 = 0 $$
#
# $$\sum_{a=1}^n  p_a f_r(x_a) - <f_r(x)>_{obs} = 0 $$
#
# On the PDF we show that the corresponding Hamiltonian is:
#
# $$H(x_a, \vec{\lambda}) = - \sum_{r=1}^{m}\lambda_i f_i(x_a)$$
#
#
# ### Analytical derivation of the tuned Lagrangian multipliers as functions of the constraints.
#
# Adopting the notation to our specific model, we set $K=1$, and rename:
#
# $x_a \rightarrow \vec{\sigma^{(a)}}, m \rightarrow S, f_r(x) \rightarrow \pi_i(\vec{\sigma}) = \sigma_i$
#
# We start considering the following Hamiltonian:
#
# $H(\vec{\sigma}, \vec{\lambda}) = - \sum_{i=1}^{S}\lambda_i f_i(\sigma) = - \sum_{i=1}^{S}\lambda_i \sigma_i $
#
# Manipulating the partition function
#
# $$Z(\vec{\lambda}) = \sum_{\{\vec{\sigma}\}} \exp\{\sum_{i=1}^S \lambda_i \sigma_i\} = \
#     \sum_{\{\vec{\sigma}\}} \prod_{i=1}^S\exp\{\lambda_i \sigma_i\} = \
#     \prod_{i=1}^S \sum_{\sigma_i = \pm 1} \exp\{\lambda_i \sigma_i\}  = \
#     2^S \prod_{i=1}^S \cosh(\lambda_i)$$
#
# Hence we can compute analytically the expected value for each variable $\sigma_i$ for a given value of $\vec{\lambda}$
#
# $$ <\sigma_i>_{model(\vec{\lambda})} = \sum_{\{\vec{\sigma}\}} \sigma_i P(\vec{\sigma}/\vec{\lambda}) = \
# \frac{\sum_{\sigma_i \pm 1} \sigma_i e^{\lambda_i \sigma_i}}{2 cosh(\lambda_i)} = tanh(\lambda_i) $$
#
# Now we impose $\forall i$ $m_i = <\sigma_i>_{model(\vec{\lambda})}$
#
# $m_i = tanh(\lambda_i) $
#
# and inverting the system we find
#
# $ \lambda_i = tanh^{-1}(m_i) = \frac{1}{2} \cdot ln(\frac{1 + m_i}{1 - m_i} )$

# %% [markdown]
# Here we apply the formula just obtained to compute the lagrangian parameters for the model Max Ent 1

# %%
m_i = 2*p_i - 1
print(m_i.max(), m_i.min())
# PROBLEM: too much variance depending on epsilon...
eps = 0
l_i = np.arctanh(m_i- np.sign(m_i)*eps) # same function
print(l_i.max(),l_i.min())
# Out:
# 1.0 -0.99
# inf -2.6466524123622457
# /home/francesco/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in arctanh
#   """

# %%
# first we remove from the plots the infinite eigenvalues
l_i_sorted = l_i[np.isfinite(l_i)]
# then we sort the remaining one for the first plot
l_i_sorted.sort()

fig, ax = plt.subplots(ncols=2, figsize=(14, 6))
# left panel
ax[0].plot(l_i_sorted)
ax[0].set_xlabel("sorted indices", fontsize = 14)
ax[0].set_ylabel("Lagrange parameters", fontsize = 14)
# right panel
counts, bin_extremes1, _ = ax[1].hist(l_i_sorted, bins = 15, histtype = 'step', density = False)
bin_centers1 = (bin_extremes1[1:] + bin_extremes1[:-1])/2
ax[1].errorbar(bin_centers1, counts, np.sqrt(counts), fmt = '.', label = 'entries with \npoisson erorr')
ax[1].set_xlabel("Lagrange parameters", fontsize = 14)
ax[1].set_ylabel("occurrencies", fontsize = 14)
plt.legend()
plt.show()

# %% [markdown]
# ## Theoric estimate of the parameters
#
# $$K = -\frac{1}{2}\frac{S}{Var(M)_{obs}} \\ \lambda_i = tanh^{-1}(m_i) + \frac{<M>_{obs}}{Var(M)_{obs}}$$

# %%
# total magnetization
M = m_i.mean()
# variance of the magnetization
VM = m_i.var()
#
K = -0.5*S/VM
print(K)
# saddle-point lambda_i - there is again the problem with regularization for m_i = +/- 1
eps = 10**-6
sp_l_i = np.arctanh(m_i - np.sign(m_i)*eps) + M/VM
print(sp_l_i.max(), sp_l_i.min())
# Out:
# -308.40042553350946
# 6.722188602438023 -3.1787421804153793

# %% [markdown]
# ## 4 - Max Ent 2
#
# Now we consider a new Hamiltonian
#
# $H(\vec{\sigma}, \vec{\lambda}, K) = - \frac{K}{S}\sum_{i,j}\sigma_i\sigma_j - \sum_{i=1}^{S}\lambda_i \sigma_i$
#
#
#
# ### Constraints for Max Ent 2
#
# The constraints that we are going to use are:
# * $m_i = <\sigma_i>_{model} = C_i(\vec{\sigma}) $ with coupled parameters $\lambda_i, i = 1,\ldots, S$
# * $\frac{<(S_+ - S_-)^2>_{exp}}{S} = \frac{<(\sum_{j=1}^{S}\sigma_j)^2>_{model}}{S} = \frac{C_0(\vec{\sigma})}{S}$ with coupled parameter $\lambda_0 = K$
#
# To initialize the Lagrange multipliers we have two possible choices: extracting them from a gaussian distribution centered in 0 or to take the initial $\lambda_i$ as the one of the previous point and for $K'$ using a gaussian with variance that is a funtion of S. [WORK IN PROGRESS]
#
# ### Gradient descent function
#
# The objective function that we want to minimize is the Kullback–Leibler divergence $D_{KL}(P_{exp}/P_{model})$.
#
# The derivatives of the KL-divergence w.r.t. the Lagrangian multipliers are:
#
# $$ \frac{\partial D_{KL}}{\partial \lambda_a} = <C_a(\vec{\sigma})>_{model}-<C_a(\vec{\sigma})>_{exp} $$
#
# More in concrete:
#
# $$\frac{\partial D_{KL}(t)}{\partial \lambda_0} = \frac{<(\sum_{j=1}^{S}\sigma_j)^2>_{model(t)}}{S} - \frac{<(S_+ - S_-)^2>_{exp}}{S}  $$
#
# $$\frac{\partial D_{KL}(t)}{\partial \lambda_i} = <\sigma_i>_{model(t)} - m_i $$
#
#
# Thus the update rule for gradient descent will be:
#
# $$\lambda_a(t+1) \leftarrow \lambda_a(t) - \eta \cdot \frac{\partial D_{KL}(t)}{\partial \lambda_a}$$
#
#
# ### Stopping criteria
# Then we want to run the cycle of Metropolis and gradient descent until a stopping criteria is met.
# Possible choices are:
# * fixed number of iterations
# * margin of improvement under a certain threshold

# %%
def gradient(model_configs, exp_constraints):
    update1 = pairing_vec(model_configs) - exp_constraints[0]
    print("Model constraint C_0: ", pairing_vec(model_configs))
    print("Observed constraint C_0: ", exp_constraints[0])
    update2 = model_m(model_configs) - exp_constraints[1:]
    
    #update2 = model_m(model_configs) - exp_constraints    
    gradient = np.concatenate((update1[np.newaxis], update2))
    return gradient

def adam(grad, m, s, beta1=0.9, beta2=0.99, e=1e-8):
    # m = momentum = 0.9 last_m + 0.1 new_gradient
    m = beta1*m+(1-beta1)*grad
    # s = second moment = 0.99 last_s + 0.01 new_gradient**2 (elementwise?)
    s = beta2*s+(1-beta2)*(grad**2)
    m_c = m/(1-beta1)
    s_c = s/(1-beta2)
    # return new_m, new_s and adam_gradient
    return m, s, (m_c/np.sqrt(s_c+e))

# %%
def pairing(configs):
    return np.power(configs.sum(),2)/S

def pairing_vec(configs):
    #print("Configs shape (n,S): ", configs.shape)
    Spm = configs.sum(axis=1)
    #print("Summing over i for each config: (n)", Spm.shape)
    mean_Spm = Spm.mean()
    return np.power(mean_Spm,2)/S

def model_m(configs):
    # assuming configs have a shape of (n, S) with S = 299
    return configs.mean(axis=0)


def compute_energy(config, L_multipliers):
    """Computes the energy of a configuration."""
    model_pair = pairing(config) # C_0/S
    #model_m_i = model_m(configs)
    model_parameters = np.concatenate((model_pair[np.newaxis], config))
    # L_multipliers[0] = K
    return -np.dot(model_parameters[1:], L_multipliers[1:]) - model_parameters[0]*L_multipliers[0]

# %%
def METRO(lagrange_multipliers, M=1e4, N=100):
    configs = []
    configuration = np.random.choice([+1,-1], size = 299)
    flip_spins = np.random.randint(low = 0, high = 299, size = int(M))
    for index in flip_spins:
        new = np.copy(configuration) # !!!!!!!
        new[index] = -configuration[index] # !!!!!!!
        #print(new[index], configuration[index]) flipping works
        if acceptance(new, configuration, lagrange_multipliers):     # !!!!!
            configuration = new
            configs.append(configuration)    
    return np.array(configs[-N:])

def acceptance(new, old, lagrange_multipliers):
    """Implements Metropolis choice."""
    # regularizer?
    en1 = compute_energy(new, lagrange_multipliers)
    en2 = compute_energy(old, lagrange_multipliers)

    if  (en1-en2) < 0:
        #print("New energy: ", en1) - high and always negative, but seems to work
        return True
    else:
        P = np.random.random()
        if P < np.exp(-(en1-en2)): #in teoria no <------------------- BETA?
            #print("New energy: ", en1) -  high and always negative, but seems to work
            return True
        else:
            return False

# %%
# Hyperparameters

# and the number of iterations
max_iter = 300

#suppression = np.arange(1,max_iter+1)
# the learning rate
eta = 0.1

#lagrange_multipliers = np.concatenate((np.array([K]), sp_l_i))
lagrange_multipliers = np.random.randn(300)
print("Theorical K: ", K)
exp_constraints = np.concatenate((C_0_over_S[np.newaxis], m_i))
print(lagrange_multipliers[0]*exp_constraints[0])
mean_sq_loss = np.zeros(max_iter) # gradient square sum
m = 0; s=0

from tqdm import tnrange
for i in tnrange(max_iter):
    configs = METRO(lagrange_multipliers)
    g = gradient(configs, exp_constraints)
    print("First component of g:", g[0])
    m, s, update = adam(g, m, s)
    print("First component of adams:", update[0])
    lagrange_multipliers = lagrange_multipliers - eta*update
    print("K : ", lagrange_multipliers[0])
    #lagrange_multipliers[0] = lagrange_multipliers[0] - eta*update[0]
    #lagrange_multipliers[1:] = lagrange_multipliers[1:] - eta*update[1:]
    #gradients.append(g[:])
    #print(update[0])
    #print(lagrange_multipliers[0])
    #print(g[0])
    mean_sq_loss[i] = np.power(g,2).sum()
    print("Squared gradient: ", mean_sq_loss[i])
# Out:
# Theorical K:  -308.40042553350946
# -28.646440217945504
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# Observed constraint C_0:  21.32829431438127
# First component of g: 6.464834782608694
# First component of adams: 0.20900964368494804
# K :  0.6081035794314369
# Squared gradient:  129.6459887664272
# Model constraint C_0:  17.395633444816056
# Observed constraint C_0:  21.32829431438127
# First component of g: -3.9326608695652148
# First component of adams: 0.14024278695967918
# K :  0.594079300735469
# Squared gradient:  104.81532151500943
# Model constraint C_0:  20.118908361204014
# Observed constraint C_0:  21.32829431438127
# First component of g: -1.2093859531772573
# First component of adams: 0.11182384283784265
# K :  0.5828969164516847
# Squared gradient:  86.93091438374246
# Model constraint C_0:  14.67470769230769
# Observed constraint C_0:  21.32829431438127
# First component of g: -6.653586622073581
# First component of adams: 0.018056506863794
# K :  0.5810912657653053
# Squared gradient:  124.59971493743652
# Model constraint C_0:  18.652516387959867
# Observed constraint C_0:  21.32829431438127
# First component of g: -2.6757779264214037
# First component of adams: -0.017101769593849122
# K :  0.5828014427246903
# Squared gradient:  102.05008751152403
# Model constraint C_0:  7.28770033444816
# Observed constraint C_0:  21.32829431438127
# First component of g: -14.04059397993311
# First component of adams: -0.188834059644214
# K :  0.6016848486891117
# Squared gradient:  289.9029793093339
# Model constraint C_0:  16.33182073578595
# Observed constraint C_0:  21.32829431438127
# First component of g: -4.996473578595321
# First component of adams: -0.23244752473339764
# K :  0.6249296011624514
# Squared gradient:  108.48264822160112
# Model constraint C_0:  11.56334448160535
# Observed constraint C_0:  21.32829431438127
# First component of g: -9.76494983277592
# First component of adams: -0.32954475443480796
# K :  0.6578840766059323
# Squared gradient:  195.06054523663053
# Model constraint C_0:  25.57108227424749
# Observed constraint C_0:  21.32829431438127
# First component of g: 4.24278795986622
# First component of adams: -0.24498022232477892
# K :  0.6823820988384102
# Squared gradient:  99.50714967238576
# Model constraint C_0:  13.139740468227425
# Observed constraint C_0:  21.32829431438127
# First component of g: -8.188553846153846
# First component of adams: -0.32211892121101976
# K :  0.7145939909595121
# Squared gradient:  163.84031409136094
# Model constraint C_0:  27.62265685618729
# Observed constraint C_0:  21.32829431438127
# First component of g: 6.29436254180602
# First component of adams: -0.21216545290225994
# K :  0.7358105362497381
# Squared gradient:  129.84889980769074
# Model constraint C_0:  14.959646822742473
# Observed constraint C_0:  21.32829431438127
# First component of g: -6.368647491638798
# First component of adams: -0.2706847019057735
# K :  0.7628790064403155
# Squared gradient:  149.19157087275715
# Model constraint C_0:  20.578038795986622
# Observed constraint C_0:  21.32829431438127
# First component of g: -0.7502555183946491
# First component of adams: -0.2542306612339774
# K :  0.7883020725637132
# Squared gradient:  74.60398334288162

# %%
plt.plot(mean_sq_loss)
plt.show()
#bk = np.concatenate((np.array([K]), sp_l_i))
#l = np.power(lagrange_multipliers-bk,2)
#print(l)
n, bins, _ = plt.hist(lagrange_multipliers[1:], histtype = 'step', label = 'metro')
plt.hist(sp_l_i, bins = bins, histtype = 'step', label = 'theorical')
plt.legend()
plt.show()
#gradients = np.array(gradients[-100:]).flatten()
#plt.hist(gradients)
#plt.show()

# %% [markdown]
# ## 6 - Max Ent 3
#
# $ H = \sum_{i=1}^S \lambda_i x_i + \frac{1}{2}\sum_{i,j=1}^S M_{ij}x_i x_j$
#
# $M_{ij}^{-1} = Cov(x_i,x_j)_{emp}$
#
# $\lambda_i = - \sum_{j=1}^S M_{ij}x_j$

# %% [markdown]
# First of all we consider the matrix X of all the aboundances for all the subplots. It is a matrix of N rows and S columns.

# %%
X = cell_pop_M.reshape((200,299))

# %% [markdown]
# Then we compute for each species the mean and the standard deviation

# %%
x_mean = X.mean(axis = 0)
x_std = X.std(axis = 0)

# %% [markdown]
# We keep only those species that satisfy:
#
# $<x_i>_{emp} - \sigma_{x_i} > 0$

# %%
aboundance_mask = x_mean - x_std > 0 
X_most_ab = X[:,aboundance_mask]

# %% [markdown]
# In this way we reduce the number of species from 299 to 52:

# %%
print(X_most_ab.shape[1])
# Out:
# 52

# %% [markdown]
# Now we compute the inverse of the interaction matrix M as the covariance matrix of the abundances of the selected species and from that we obtain M inverting $M^{-1}$

# %%
inv_M = np.cov(X_most_ab.T)
M = np.linalg.inv(inv_M)

# %% [markdown]
# We now impose that the self interacting terms (diagonal) are null

# %%
mask = np.eye(M.shape[0]).astype('bool')
M[mask] = 0
print(M.trace())
# Out:
# 0.0

# %%
print("Max interaction element: %.3f"%M.max())
print("Min interaction element: %.3f"%M.min())
# Out:
# Max interaction element: 0.176
# Min interaction element: -0.093

# %% [markdown]
# At this point we can compute $\lambda_i$ with the formula reported at the begin of this section

# %%
X_most_mean = X_most_ab.mean(axis = 0)
lamb = -np.dot(M,X_most_mean)
#plt.hist(lamb)
#plt.show()
#plt.close()

# %% [markdown]
# # 7 - Analysis of the interaction network

# %% [markdown]
# In this first histogram we can see the distribuition of the entries of the matrix $M$. We can notice that the distribution is peaked around the zero (with a number of entries much higher than the length of the diagonal, i.e. ~600 vs 52) and it is more or less symmetric around zero.

# %%
plt.figure(figsize = (8,6))
plt.hist(M.flatten(), bins = 25, histtype = 'step', density = False)
plt.xlim(-0.10, +0.10)
plt.xlabel("entries of $M_{ij}$", fontsize = 14)
plt.ylabel("occurrencies", fontsize = 14)
plt.title("Total number of entries: %d"%(len(M)**2), fontsize = 16)
plt.show()

# %% [markdown]
# Now we want to put a threshold $\theta$ on the absolute value of the entries of M. We choose as range for the threshold $[0,max(abs(M))]$

# %%
def laplacian(A):
    degrees = A.sum(axis = 0)
    K = np.diag(degrees)
    return K-A

# %%
# number of threshold we want to use
T = 2000
# consider evenly spaced thresholds
thresholds = np.linspace(0, np.max(np.abs(M)), T)
# placehholder for the number of connected components for each threshold
connected_components = np.zeros(T)
# this is the order of magnitude under which we consider zero an eigenvalue
sensibility = 10**-12 
#OBS: it can't be taken too small otherwise it would count 0 connected components for theta = 0, that is absurd

for i,theta in enumerate(thresholds):
    # elementwise boolean operation, returns a matrix of True and False
    threshold_mask = np.abs(M) > theta 
    # we can compute directly the adjacency matrix from the threshold mask
    A = threshold_mask.astype(int)
    # compute the laplacian of A
    L = laplacian(A)
    # eigenvalue decomposition; "eigh" used for symmetric matrix -> default format fo eigenvalues is set to float
    eig_values,V = np.linalg.eigh(L)
    # we take as zero all the eigenvalues with absolute value under the chosen sensibility 
    almost_zero = np.abs(eig_values) < sensibility
    # number of conncected components = number of zero eigenvalues (or equivalently degeneracy of eigval 0)
    connected_components[i] = np.count_nonzero(almost_zero.astype(int))

# %%
one_component_mask = connected_components == 1
theta_star = np.max(thresholds[one_component_mask])
print("Estimated theta star: %.4f"%theta_star)
# Out:
# Estimated theta star: 0.0031

# %%
plt.figure(figsize = (8,6))
plt.plot(thresholds, connected_components, label = 'connected \ncomponents')
plt.xlabel("threshold "+r"$\theta$", fontsize = 14)
plt.ylabel("# of connected components", fontsize = 14)
plt.axvline(theta_star, color = 'red', label = r'$\theta*$')
plt.legend(loc = 'center')
plt.show()

# %%
# if we are interested in the detailed correspondence between threshold and connected components
for t,c in zip(thresholds, connected_components):
    print("Threshold = %.4f, connected components = %.d"%(t,c))
# Out:
# Threshold = 0.0000, connected components = 1
# Threshold = 0.0001, connected components = 1
# Threshold = 0.0002, connected components = 1
# Threshold = 0.0003, connected components = 1
# Threshold = 0.0004, connected components = 1
# Threshold = 0.0004, connected components = 1
# Threshold = 0.0005, connected components = 1
# Threshold = 0.0006, connected components = 1
# Threshold = 0.0007, connected components = 1
# Threshold = 0.0008, connected components = 1
# Threshold = 0.0009, connected components = 1
# Threshold = 0.0010, connected components = 1
# Threshold = 0.0011, connected components = 1
# Threshold = 0.0011, connected components = 1
# Threshold = 0.0012, connected components = 1
# Threshold = 0.0013, connected components = 1
# Threshold = 0.0014, connected components = 1
# Threshold = 0.0015, connected components = 1
# Threshold = 0.0016, connected components = 1
# Threshold = 0.0017, connected components = 1
# Threshold = 0.0018, connected components = 1
# Threshold = 0.0018, connected components = 1
# Threshold = 0.0019, connected components = 1
# Threshold = 0.0020, connected components = 1
# Threshold = 0.0021, connected components = 1
# Threshold = 0.0022, connected components = 1
# Threshold = 0.0023, connected components = 1
# Threshold = 0.0024, connected components = 1
# Threshold = 0.0025, connected components = 1
# Threshold = 0.0026, connected components = 1
# Threshold = 0.0026, connected components = 1
# Threshold = 0.0027, connected components = 1
# Threshold = 0.0028, connected components = 1
# Threshold = 0.0029, connected components = 1
# Threshold = 0.0030, connected components = 1
# Threshold = 0.0031, connected components = 1
# Threshold = 0.0032, connected components = 2
# Threshold = 0.0033, connected components = 2
# Threshold = 0.0033, connected components = 2
# Threshold = 0.0034, connected components = 2
# Threshold = 0.0035, connected components = 2
# Threshold = 0.0036, connected components = 2
# Threshold = 0.0037, connected components = 2
# Threshold = 0.0038, connected components = 2
# Threshold = 0.0039, connected components = 3
# Threshold = 0.0040, connected components = 3
# Threshold = 0.0040, connected components = 3
# Threshold = 0.0041, connected components = 3
# Threshold = 0.0042, connected components = 3
# Threshold = 0.0043, connected components = 3
# Threshold = 0.0044, connected components = 3
# Threshold = 0.0045, connected components = 3
# Threshold = 0.0046, connected components = 3
# Threshold = 0.0047, connected components = 3
# Threshold = 0.0048, connected components = 3
# Threshold = 0.0048, connected components = 3
# Threshold = 0.0049, connected components = 3
# Threshold = 0.0050, connected components = 3
# Threshold = 0.0051, connected components = 3
# Threshold = 0.0052, connected components = 3
# Threshold = 0.0053, connected components = 3
# Threshold = 0.0054, connected components = 3
# Threshold = 0.0055, connected components = 3
# Threshold = 0.0055, connected components = 3
# Threshold = 0.0056, connected components = 3
# Threshold = 0.0057, connected components = 3
# Threshold = 0.0058, connected components = 3
# Threshold = 0.0059, connected components = 3
# Threshold = 0.0060, connected components = 3
# Threshold = 0.0061, connected components = 3
# Threshold = 0.0062, connected components = 3
# Threshold = 0.0063, connected components = 3
# Threshold = 0.0063, connected components = 3
# Threshold = 0.0064, connected components = 3
# Threshold = 0.0065, connected components = 3
# Threshold = 0.0066, connected components = 3
# Threshold = 0.0067, connected components = 3
# Threshold = 0.0068, connected components = 3
# Threshold = 0.0069, connected components = 3
# Threshold = 0.0070, connected components = 3
# Threshold = 0.0070, connected components = 3
# Threshold = 0.0071, connected components = 3
# Threshold = 0.0072, connected components = 3
# Threshold = 0.0073, connected components = 3
# Threshold = 0.0074, connected components = 3
# Threshold = 0.0075, connected components = 3
# Threshold = 0.0076, connected components = 3
# Threshold = 0.0077, connected components = 3
# Threshold = 0.0077, connected components = 4
# Threshold = 0.0078, connected components = 4
# Threshold = 0.0079, connected components = 4
# Threshold = 0.0080, connected components = 4
# Threshold = 0.0081, connected components = 4
# Threshold = 0.0082, connected components = 4
# Threshold = 0.0083, connected components = 4
# Threshold = 0.0084, connected components = 4
# Threshold = 0.0085, connected components = 4
# Threshold = 0.0085, connected components = 4
# Threshold = 0.0086, connected components = 4
# Threshold = 0.0087, connected components = 4
# Threshold = 0.0088, connected components = 4
# Threshold = 0.0089, connected components = 4
# Threshold = 0.0090, connected components = 4
# Threshold = 0.0091, connected components = 4
# Threshold = 0.0092, connected components = 4
# Threshold = 0.0092, connected components = 4
# Threshold = 0.0093, connected components = 4
# Threshold = 0.0094, connected components = 4
# Threshold = 0.0095, connected components = 4
# Threshold = 0.0096, connected components = 4
# Threshold = 0.0097, connected components = 5
# Threshold = 0.0098, connected components = 5
# Threshold = 0.0099, connected components = 5
# Threshold = 0.0099, connected components = 5
# Threshold = 0.0100, connected components = 5
# Threshold = 0.0101, connected components = 5
# Threshold = 0.0102, connected components = 5
# Threshold = 0.0103, connected components = 6
# Threshold = 0.0104, connected components = 6
# Threshold = 0.0105, connected components = 6
# Threshold = 0.0106, connected components = 6
# Threshold = 0.0107, connected components = 6
# Threshold = 0.0107, connected components = 6
# Threshold = 0.0108, connected components = 6
# Threshold = 0.0109, connected components = 6
# Threshold = 0.0110, connected components = 6
# Threshold = 0.0111, connected components = 7
# Threshold = 0.0112, connected components = 7
# Threshold = 0.0113, connected components = 7
# Threshold = 0.0114, connected components = 7
# Threshold = 0.0114, connected components = 7
# Threshold = 0.0115, connected components = 7
# Threshold = 0.0116, connected components = 7
# Threshold = 0.0117, connected components = 7
# Threshold = 0.0118, connected components = 7
# Threshold = 0.0119, connected components = 7
# Threshold = 0.0120, connected components = 7
# Threshold = 0.0121, connected components = 7
# Threshold = 0.0121, connected components = 7
# Threshold = 0.0122, connected components = 7
# Threshold = 0.0123, connected components = 7
# Threshold = 0.0124, connected components = 7
# Threshold = 0.0125, connected components = 7
# Threshold = 0.0126, connected components = 7
# Threshold = 0.0127, connected components = 7
# Threshold = 0.0128, connected components = 7
# Threshold = 0.0129, connected components = 7
# Threshold = 0.0129, connected components = 7
# Threshold = 0.0130, connected components = 7
# Threshold = 0.0131, connected components = 7
# Threshold = 0.0132, connected components = 7
# Threshold = 0.0133, connected components = 7
# Threshold = 0.0134, connected components = 7
# Threshold = 0.0135, connected components = 7
# Threshold = 0.0136, connected components = 8
# Threshold = 0.0136, connected components = 8
# Threshold = 0.0137, connected components = 8
# Threshold = 0.0138, connected components = 8
# Threshold = 0.0139, connected components = 8
# Threshold = 0.0140, connected components = 8
# Threshold = 0.0141, connected components = 8
# Threshold = 0.0142, connected components = 8
# Threshold = 0.0143, connected components = 8
# Threshold = 0.0144, connected components = 8
# Threshold = 0.0144, connected components = 8
# Threshold = 0.0145, connected components = 8
# Threshold = 0.0146, connected components = 8
# Threshold = 0.0147, connected components = 8
# Threshold = 0.0148, connected components = 8
# Threshold = 0.0149, connected components = 8
# Threshold = 0.0150, connected components = 9
# Threshold = 0.0151, connected components = 9
# Threshold = 0.0151, connected components = 9
# Threshold = 0.0152, connected components = 9
# Threshold = 0.0153, connected components = 9
# Threshold = 0.0154, connected components = 9
# Threshold = 0.0155, connected components = 9
# Threshold = 0.0156, connected components = 9
# Threshold = 0.0157, connected components = 9
# Threshold = 0.0158, connected components = 9
# Threshold = 0.0158, connected components = 9
# Threshold = 0.0159, connected components = 9
# Threshold = 0.0160, connected components = 9
# Threshold = 0.0161, connected components = 9
# Threshold = 0.0162, connected components = 9
# Threshold = 0.0163, connected components = 9
# Threshold = 0.0164, connected components = 9
# Threshold = 0.0165, connected components = 9
# Threshold = 0.0166, connected components = 9
# Threshold = 0.0166, connected components = 9
# Threshold = 0.0167, connected components = 9
# Threshold = 0.0168, connected components = 9
# Threshold = 0.0169, connected components = 9
# Threshold = 0.0170, connected components = 9
# Threshold = 0.0171, connected components = 9
# Threshold = 0.0172, connected components = 9
# Threshold = 0.0173, connected components = 9
# Threshold = 0.0173, connected components = 9
# Threshold = 0.0174, connected components = 9
# Threshold = 0.0175, connected components = 9
# Threshold = 0.0176, connected components = 9
# Threshold = 0.0177, connected components = 9
# Threshold = 0.0178, connected components = 10
# Threshold = 0.0179, connected components = 10
# Threshold = 0.0180, connected components = 10
# Threshold = 0.0180, connected components = 10
# Threshold = 0.0181, connected components = 10
# Threshold = 0.0182, connected components = 10
# Threshold = 0.0183, connected components = 10
# Threshold = 0.0184, connected components = 10
# Threshold = 0.0185, connected components = 10
# Threshold = 0.0186, connected components = 10
# Threshold = 0.0187, connected components = 10
# Threshold = 0.0188, connected components = 10
# Threshold = 0.0188, connected components = 10
# Threshold = 0.0189, connected components = 10
# Threshold = 0.0190, connected components = 10
# Threshold = 0.0191, connected components = 10
# Threshold = 0.0192, connected components = 11
# Threshold = 0.0193, connected components = 11
# Threshold = 0.0194, connected components = 11
# Threshold = 0.0195, connected components = 11
# Threshold = 0.0195, connected components = 11
# Threshold = 0.0196, connected components = 11
# Threshold = 0.0197, connected components = 11
# Threshold = 0.0198, connected components = 11
# Threshold = 0.0199, connected components = 11
# Threshold = 0.0200, connected components = 11
# Threshold = 0.0201, connected components = 11
# Threshold = 0.0202, connected components = 11
# Threshold = 0.0202, connected components = 11
# Threshold = 0.0203, connected components = 11
# Threshold = 0.0204, connected components = 11
# Threshold = 0.0205, connected components = 11
# Threshold = 0.0206, connected components = 11
# Threshold = 0.0207, connected components = 11
# Threshold = 0.0208, connected components = 11
# Threshold = 0.0209, connected components = 11
# Threshold = 0.0210, connected components = 11
# Threshold = 0.0210, connected components = 11
# Threshold = 0.0211, connected components = 11
# Threshold = 0.0212, connected components = 11
# Threshold = 0.0213, connected components = 11
# Threshold = 0.0214, connected components = 11
# Threshold = 0.0215, connected components = 11
# Threshold = 0.0216, connected components = 11
# Threshold = 0.0217, connected components = 12
# Threshold = 0.0217, connected components = 12
# Threshold = 0.0218, connected components = 12
# Threshold = 0.0219, connected components = 12
# Threshold = 0.0220, connected components = 12
# Threshold = 0.0221, connected components = 12
# Threshold = 0.0222, connected components = 12
# Threshold = 0.0223, connected components = 12
# Threshold = 0.0224, connected components = 12
# Threshold = 0.0225, connected components = 12
# Threshold = 0.0225, connected components = 12
# Threshold = 0.0226, connected components = 12
# Threshold = 0.0227, connected components = 12
# Threshold = 0.0228, connected components = 12
# Threshold = 0.0229, connected components = 13
# Threshold = 0.0230, connected components = 13
# Threshold = 0.0231, connected components = 13
# Threshold = 0.0232, connected components = 13
# Threshold = 0.0232, connected components = 13
# Threshold = 0.0233, connected components = 13
# Threshold = 0.0234, connected components = 13
# Threshold = 0.0235, connected components = 13
# Threshold = 0.0236, connected components = 13
# Threshold = 0.0237, connected components = 13
# Threshold = 0.0238, connected components = 13
# Threshold = 0.0239, connected components = 13
# Threshold = 0.0239, connected components = 13
# Threshold = 0.0240, connected components = 14
# Threshold = 0.0241, connected components = 14
# Threshold = 0.0242, connected components = 14
# Threshold = 0.0243, connected components = 14
# Threshold = 0.0244, connected components = 14
# Threshold = 0.0245, connected components = 14
# Threshold = 0.0246, connected components = 15
# Threshold = 0.0247, connected components = 15
# Threshold = 0.0247, connected components = 15
# Threshold = 0.0248, connected components = 15
# Threshold = 0.0249, connected components = 15
# Threshold = 0.0250, connected components = 15
# Threshold = 0.0251, connected components = 15
# Threshold = 0.0252, connected components = 15
# Threshold = 0.0253, connected components = 15
# Threshold = 0.0254, connected components = 15
# Threshold = 0.0254, connected components = 15
# Threshold = 0.0255, connected components = 15
# Threshold = 0.0256, connected components = 15
# Threshold = 0.0257, connected components = 15
# Threshold = 0.0258, connected components = 16
# Threshold = 0.0259, connected components = 16
# Threshold = 0.0260, connected components = 16
# Threshold = 0.0261, connected components = 16
# Threshold = 0.0261, connected components = 16
# Threshold = 0.0262, connected components = 16
# Threshold = 0.0263, connected components = 16
# Threshold = 0.0264, connected components = 16
# Threshold = 0.0265, connected components = 16
# Threshold = 0.0266, connected components = 16
# Threshold = 0.0267, connected components = 16
# Threshold = 0.0268, connected components = 16
# Threshold = 0.0269, connected components = 16
# Threshold = 0.0269, connected components = 17
# Threshold = 0.0270, connected components = 17
# Threshold = 0.0271, connected components = 19
# Threshold = 0.0272, connected components = 19
# Threshold = 0.0273, connected components = 19
# Threshold = 0.0274, connected components = 19
# Threshold = 0.0275, connected components = 19
# Threshold = 0.0276, connected components = 19
# Threshold = 0.0276, connected components = 19
# Threshold = 0.0277, connected components = 19
# Threshold = 0.0278, connected components = 19
# Threshold = 0.0279, connected components = 19
# Threshold = 0.0280, connected components = 19
# Threshold = 0.0281, connected components = 19
# Threshold = 0.0282, connected components = 19
# Threshold = 0.0283, connected components = 19
# Threshold = 0.0283, connected components = 19
# Threshold = 0.0284, connected components = 20
# Threshold = 0.0285, connected components = 20
# Threshold = 0.0286, connected components = 20
# Threshold = 0.0287, connected components = 20
# Threshold = 0.0288, connected components = 20
# Threshold = 0.0289, connected components = 20
# Threshold = 0.0290, connected components = 20
# Threshold = 0.0291, connected components = 20
# Threshold = 0.0291, connected components = 20
# Threshold = 0.0292, connected components = 20
# Threshold = 0.0293, connected components = 20
# Threshold = 0.0294, connected components = 20
# Threshold = 0.0295, connected components = 20
# Threshold = 0.0296, connected components = 20
# Threshold = 0.0297, connected components = 20
# Threshold = 0.0298, connected components = 21
# Threshold = 0.0298, connected components = 21
# Threshold = 0.0299, connected components = 21
# Threshold = 0.0300, connected components = 21
# Threshold = 0.0301, connected components = 21
# Threshold = 0.0302, connected components = 21
# Threshold = 0.0303, connected components = 21
# Threshold = 0.0304, connected components = 21
# Threshold = 0.0305, connected components = 21
# Threshold = 0.0306, connected components = 21
# Threshold = 0.0306, connected components = 21
# Threshold = 0.0307, connected components = 21
# Threshold = 0.0308, connected components = 21
# Threshold = 0.0309, connected components = 21
# Threshold = 0.0310, connected components = 21
# Threshold = 0.0311, connected components = 21
# Threshold = 0.0312, connected components = 22
# Threshold = 0.0313, connected components = 22
# Threshold = 0.0313, connected components = 22
# Threshold = 0.0314, connected components = 22
# Threshold = 0.0315, connected components = 22
# Threshold = 0.0316, connected components = 22
# Threshold = 0.0317, connected components = 22
# Threshold = 0.0318, connected components = 22
# Threshold = 0.0319, connected components = 22
# Threshold = 0.0320, connected components = 22
# Threshold = 0.0320, connected components = 22
# Threshold = 0.0321, connected components = 22
# Threshold = 0.0322, connected components = 22
# Threshold = 0.0323, connected components = 23
# Threshold = 0.0324, connected components = 23
# Threshold = 0.0325, connected components = 23
# Threshold = 0.0326, connected components = 24
# Threshold = 0.0327, connected components = 24
# Threshold = 0.0328, connected components = 24
# Threshold = 0.0328, connected components = 24
# Threshold = 0.0329, connected components = 24
# Threshold = 0.0330, connected components = 24
# Threshold = 0.0331, connected components = 24
# Threshold = 0.0332, connected components = 24
# Threshold = 0.0333, connected components = 24
# Threshold = 0.0334, connected components = 24
# Threshold = 0.0335, connected components = 24
# Threshold = 0.0335, connected components = 24
# Threshold = 0.0336, connected components = 24
# Threshold = 0.0337, connected components = 24
# Threshold = 0.0338, connected components = 24
# Threshold = 0.0339, connected components = 24
# Threshold = 0.0340, connected components = 24
# Threshold = 0.0341, connected components = 24
# Threshold = 0.0342, connected components = 24
# Threshold = 0.0342, connected components = 24
# Threshold = 0.0343, connected components = 24
# Threshold = 0.0344, connected components = 24
# Threshold = 0.0345, connected components = 24
# Threshold = 0.0346, connected components = 24
# Threshold = 0.0347, connected components = 24
# Threshold = 0.0348, connected components = 24
# Threshold = 0.0349, connected components = 25
# Threshold = 0.0350, connected components = 25
# Threshold = 0.0350, connected components = 25
# Threshold = 0.0351, connected components = 25
# Threshold = 0.0352, connected components = 25
# Threshold = 0.0353, connected components = 25
# Threshold = 0.0354, connected components = 25
# Threshold = 0.0355, connected components = 25
# Threshold = 0.0356, connected components = 25
# Threshold = 0.0357, connected components = 25
# Threshold = 0.0357, connected components = 25
# Threshold = 0.0358, connected components = 26
# Threshold = 0.0359, connected components = 26
# Threshold = 0.0360, connected components = 26
# Threshold = 0.0361, connected components = 26
# Threshold = 0.0362, connected components = 26
# Threshold = 0.0363, connected components = 26
# Threshold = 0.0364, connected components = 26
# Threshold = 0.0364, connected components = 26
# Threshold = 0.0365, connected components = 26
# Threshold = 0.0366, connected components = 26
# Threshold = 0.0367, connected components = 26
# Threshold = 0.0368, connected components = 26
# Threshold = 0.0369, connected components = 26
# Threshold = 0.0370, connected components = 26
# Threshold = 0.0371, connected components = 26
# Threshold = 0.0372, connected components = 26
# Threshold = 0.0372, connected components = 26
# Threshold = 0.0373, connected components = 26
# Threshold = 0.0374, connected components = 26
# Threshold = 0.0375, connected components = 26
# Threshold = 0.0376, connected components = 26
# Threshold = 0.0377, connected components = 26
# Threshold = 0.0378, connected components = 26
# Threshold = 0.0379, connected components = 26
# Threshold = 0.0379, connected components = 26
# Threshold = 0.0380, connected components = 27
# Threshold = 0.0381, connected components = 27
# Threshold = 0.0382, connected components = 27
# Threshold = 0.0383, connected components = 27
# Threshold = 0.0384, connected components = 27
# Threshold = 0.0385, connected components = 27
# Threshold = 0.0386, connected components = 27
# Threshold = 0.0387, connected components = 28
# Threshold = 0.0387, connected components = 28
# Threshold = 0.0388, connected components = 28
# Threshold = 0.0389, connected components = 28
# Threshold = 0.0390, connected components = 28
# Threshold = 0.0391, connected components = 28
# Threshold = 0.0392, connected components = 28
# Threshold = 0.0393, connected components = 28
# Threshold = 0.0394, connected components = 29
# Threshold = 0.0394, connected components = 29
# Threshold = 0.0395, connected components = 29
# Threshold = 0.0396, connected components = 29
# Threshold = 0.0397, connected components = 29
# Threshold = 0.0398, connected components = 29
# Threshold = 0.0399, connected components = 29
# Threshold = 0.0400, connected components = 29
# Threshold = 0.0401, connected components = 29
# Threshold = 0.0401, connected components = 29
# Threshold = 0.0402, connected components = 29
# Threshold = 0.0403, connected components = 29
# Threshold = 0.0404, connected components = 29
# Threshold = 0.0405, connected components = 29
# Threshold = 0.0406, connected components = 30
# Threshold = 0.0407, connected components = 30
# Threshold = 0.0408, connected components = 30
# Threshold = 0.0409, connected components = 30
# Threshold = 0.0409, connected components = 30
# Threshold = 0.0410, connected components = 30
# Threshold = 0.0411, connected components = 30
# Threshold = 0.0412, connected components = 30
# Threshold = 0.0413, connected components = 30
# Threshold = 0.0414, connected components = 31
# Threshold = 0.0415, connected components = 31
# Threshold = 0.0416, connected components = 31
# Threshold = 0.0416, connected components = 31
# Threshold = 0.0417, connected components = 31
# Threshold = 0.0418, connected components = 31
# Threshold = 0.0419, connected components = 31
# Threshold = 0.0420, connected components = 31
# Threshold = 0.0421, connected components = 31
# Threshold = 0.0422, connected components = 31
# Threshold = 0.0423, connected components = 31
# Threshold = 0.0423, connected components = 31
# Threshold = 0.0424, connected components = 31
# Threshold = 0.0425, connected components = 31
# Threshold = 0.0426, connected components = 31
# Threshold = 0.0427, connected components = 31
# Threshold = 0.0428, connected components = 31
# Threshold = 0.0429, connected components = 31
# Threshold = 0.0430, connected components = 31
# Threshold = 0.0431, connected components = 31
# Threshold = 0.0431, connected components = 31
# Threshold = 0.0432, connected components = 31
# Threshold = 0.0433, connected components = 31
# Threshold = 0.0434, connected components = 31
# Threshold = 0.0435, connected components = 32
# Threshold = 0.0436, connected components = 32
# Threshold = 0.0437, connected components = 32
# Threshold = 0.0438, connected components = 32
# Threshold = 0.0438, connected components = 32
# Threshold = 0.0439, connected components = 32
# Threshold = 0.0440, connected components = 32
# Threshold = 0.0441, connected components = 32
# Threshold = 0.0442, connected components = 32
# Threshold = 0.0443, connected components = 32
# Threshold = 0.0444, connected components = 32
# Threshold = 0.0445, connected components = 32
# Threshold = 0.0445, connected components = 33
# Threshold = 0.0446, connected components = 34
# Threshold = 0.0447, connected components = 34
# Threshold = 0.0448, connected components = 34
# Threshold = 0.0449, connected components = 34
# Threshold = 0.0450, connected components = 34
# Threshold = 0.0451, connected components = 34
# Threshold = 0.0452, connected components = 34
# Threshold = 0.0453, connected components = 34
# Threshold = 0.0453, connected components = 34
# Threshold = 0.0454, connected components = 34
# Threshold = 0.0455, connected components = 34
# Threshold = 0.0456, connected components = 34
# Threshold = 0.0457, connected components = 34
# Threshold = 0.0458, connected components = 34
# Threshold = 0.0459, connected components = 34
# Threshold = 0.0460, connected components = 34
# Threshold = 0.0460, connected components = 34
# Threshold = 0.0461, connected components = 34
# Threshold = 0.0462, connected components = 34
# Threshold = 0.0463, connected components = 34
# Threshold = 0.0464, connected components = 34
# Threshold = 0.0465, connected components = 34
# Threshold = 0.0466, connected components = 34
# Threshold = 0.0467, connected components = 34
# Threshold = 0.0468, connected components = 34
# Threshold = 0.0468, connected components = 34
# Threshold = 0.0469, connected components = 34
# Threshold = 0.0470, connected components = 34
# Threshold = 0.0471, connected components = 34
# Threshold = 0.0472, connected components = 34
# Threshold = 0.0473, connected components = 34
# Threshold = 0.0474, connected components = 34
# Threshold = 0.0475, connected components = 34
# Threshold = 0.0475, connected components = 34
# Threshold = 0.0476, connected components = 34
# Threshold = 0.0477, connected components = 35
# Threshold = 0.0478, connected components = 35
# Threshold = 0.0479, connected components = 35
# Threshold = 0.0480, connected components = 35
# Threshold = 0.0481, connected components = 35
# Threshold = 0.0482, connected components = 35
# Threshold = 0.0482, connected components = 35
# Threshold = 0.0483, connected components = 35
# Threshold = 0.0484, connected components = 35
# Threshold = 0.0485, connected components = 35
# Threshold = 0.0486, connected components = 35
# Threshold = 0.0487, connected components = 35
# Threshold = 0.0488, connected components = 36
# Threshold = 0.0489, connected components = 36
# Threshold = 0.0490, connected components = 36
# Threshold = 0.0490, connected components = 36
# Threshold = 0.0491, connected components = 36
# Threshold = 0.0492, connected components = 36
# Threshold = 0.0493, connected components = 36
# Threshold = 0.0494, connected components = 36
# Threshold = 0.0495, connected components = 36
# Threshold = 0.0496, connected components = 36
# Threshold = 0.0497, connected components = 36
# Threshold = 0.0497, connected components = 36
# Threshold = 0.0498, connected components = 36
# Threshold = 0.0499, connected components = 36
# Threshold = 0.0500, connected components = 36
# Threshold = 0.0501, connected components = 36
# Threshold = 0.0502, connected components = 36
# Threshold = 0.0503, connected components = 36
# Threshold = 0.0504, connected components = 36
# Threshold = 0.0504, connected components = 36
# Threshold = 0.0505, connected components = 36
# Threshold = 0.0506, connected components = 36
# Threshold = 0.0507, connected components = 36
# Threshold = 0.0508, connected components = 36
# Threshold = 0.0509, connected components = 36
# Threshold = 0.0510, connected components = 36
# Threshold = 0.0511, connected components = 36
# Threshold = 0.0512, connected components = 36
# Threshold = 0.0512, connected components = 36
# Threshold = 0.0513, connected components = 37
# Threshold = 0.0514, connected components = 37
# Threshold = 0.0515, connected components = 37
# Threshold = 0.0516, connected components = 37
# Threshold = 0.0517, connected components = 37
# Threshold = 0.0518, connected components = 37
# Threshold = 0.0519, connected components = 37
# Threshold = 0.0519, connected components = 37
# Threshold = 0.0520, connected components = 37
# Threshold = 0.0521, connected components = 37
# Threshold = 0.0522, connected components = 37
# Threshold = 0.0523, connected components = 37
# Threshold = 0.0524, connected components = 37
# Threshold = 0.0525, connected components = 37
# Threshold = 0.0526, connected components = 37
# Threshold = 0.0526, connected components = 37
# Threshold = 0.0527, connected components = 37
# Threshold = 0.0528, connected components = 37
# Threshold = 0.0529, connected components = 37
# Threshold = 0.0530, connected components = 37
# Threshold = 0.0531, connected components = 37
# Threshold = 0.0532, connected components = 37
# Threshold = 0.0533, connected components = 37
# Threshold = 0.0534, connected components = 37
# Threshold = 0.0534, connected components = 37
# Threshold = 0.0535, connected components = 37
# Threshold = 0.0536, connected components = 37
# Threshold = 0.0537, connected components = 37
# Threshold = 0.0538, connected components = 37
# Threshold = 0.0539, connected components = 37
# Threshold = 0.0540, connected components = 37
# Threshold = 0.0541, connected components = 37
# Threshold = 0.0541, connected components = 37
# Threshold = 0.0542, connected components = 37
# Threshold = 0.0543, connected components = 37
# Threshold = 0.0544, connected components = 37
# Threshold = 0.0545, connected components = 37
# Threshold = 0.0546, connected components = 37
# Threshold = 0.0547, connected components = 37
# Threshold = 0.0548, connected components = 37
# Threshold = 0.0548, connected components = 37
# Threshold = 0.0549, connected components = 37
# Threshold = 0.0550, connected components = 37
# Threshold = 0.0551, connected components = 37
# Threshold = 0.0552, connected components = 37
# Threshold = 0.0553, connected components = 37
# Threshold = 0.0554, connected components = 37
# Threshold = 0.0555, connected components = 37
# Threshold = 0.0556, connected components = 37
# Threshold = 0.0556, connected components = 37
# Threshold = 0.0557, connected components = 37
# Threshold = 0.0558, connected components = 37
# Threshold = 0.0559, connected components = 38
# Threshold = 0.0560, connected components = 38
# Threshold = 0.0561, connected components = 38
# Threshold = 0.0562, connected components = 38
# Threshold = 0.0563, connected components = 38
# Threshold = 0.0563, connected components = 38
# Threshold = 0.0564, connected components = 38
# Threshold = 0.0565, connected components = 38
# Threshold = 0.0566, connected components = 38
# Threshold = 0.0567, connected components = 38
# Threshold = 0.0568, connected components = 38
# Threshold = 0.0569, connected components = 38
# Threshold = 0.0570, connected components = 38
# Threshold = 0.0571, connected components = 38
# Threshold = 0.0571, connected components = 38
# Threshold = 0.0572, connected components = 38
# Threshold = 0.0573, connected components = 38
# Threshold = 0.0574, connected components = 38
# Threshold = 0.0575, connected components = 38
# Threshold = 0.0576, connected components = 38
# Threshold = 0.0577, connected components = 38
# Threshold = 0.0578, connected components = 38
# Threshold = 0.0578, connected components = 38
# Threshold = 0.0579, connected components = 38
# Threshold = 0.0580, connected components = 38
# Threshold = 0.0581, connected components = 38
# Threshold = 0.0582, connected components = 38
# Threshold = 0.0583, connected components = 38
# Threshold = 0.0584, connected components = 38
# Threshold = 0.0585, connected components = 38
# Threshold = 0.0585, connected components = 38
# Threshold = 0.0586, connected components = 38
# Threshold = 0.0587, connected components = 38
# Threshold = 0.0588, connected components = 38
# Threshold = 0.0589, connected components = 38
# Threshold = 0.0590, connected components = 38
# Threshold = 0.0591, connected components = 38
# Threshold = 0.0592, connected components = 38
# Threshold = 0.0593, connected components = 38
# Threshold = 0.0593, connected components = 38
# Threshold = 0.0594, connected components = 38
# Threshold = 0.0595, connected components = 39
# Threshold = 0.0596, connected components = 39
# Threshold = 0.0597, connected components = 39
# Threshold = 0.0598, connected components = 39
# Threshold = 0.0599, connected components = 39
# Threshold = 0.0600, connected components = 39
# Threshold = 0.0600, connected components = 39
# Threshold = 0.0601, connected components = 39
# Threshold = 0.0602, connected components = 39
# Threshold = 0.0603, connected components = 39
# Threshold = 0.0604, connected components = 39
# Threshold = 0.0605, connected components = 39
# Threshold = 0.0606, connected components = 39
# Threshold = 0.0607, connected components = 39
# Threshold = 0.0607, connected components = 39
# Threshold = 0.0608, connected components = 39
# Threshold = 0.0609, connected components = 39
# Threshold = 0.0610, connected components = 39
# Threshold = 0.0611, connected components = 39
# Threshold = 0.0612, connected components = 39
# Threshold = 0.0613, connected components = 39
# Threshold = 0.0614, connected components = 39
# Threshold = 0.0615, connected components = 39
# Threshold = 0.0615, connected components = 39
# Threshold = 0.0616, connected components = 39
# Threshold = 0.0617, connected components = 39
# Threshold = 0.0618, connected components = 39
# Threshold = 0.0619, connected components = 39
# Threshold = 0.0620, connected components = 39
# Threshold = 0.0621, connected components = 39
# Threshold = 0.0622, connected components = 39
# Threshold = 0.0622, connected components = 39
# Threshold = 0.0623, connected components = 39
# Threshold = 0.0624, connected components = 39
# Threshold = 0.0625, connected components = 39
# Threshold = 0.0626, connected components = 39
# Threshold = 0.0627, connected components = 39
# Threshold = 0.0628, connected components = 40
# Threshold = 0.0629, connected components = 40
# Threshold = 0.0629, connected components = 40
# Threshold = 0.0630, connected components = 40
# Threshold = 0.0631, connected components = 40
# Threshold = 0.0632, connected components = 40
# Threshold = 0.0633, connected components = 40
# Threshold = 0.0634, connected components = 40
# Threshold = 0.0635, connected components = 40
# Threshold = 0.0636, connected components = 40
# Threshold = 0.0637, connected components = 40
# Threshold = 0.0637, connected components = 40
# Threshold = 0.0638, connected components = 40
# Threshold = 0.0639, connected components = 40
# Threshold = 0.0640, connected components = 40
# Threshold = 0.0641, connected components = 40
# Threshold = 0.0642, connected components = 40
# Threshold = 0.0643, connected components = 40
# Threshold = 0.0644, connected components = 40
# Threshold = 0.0644, connected components = 40
# Threshold = 0.0645, connected components = 40
# Threshold = 0.0646, connected components = 40
# Threshold = 0.0647, connected components = 40
# Threshold = 0.0648, connected components = 40
# Threshold = 0.0649, connected components = 40
# Threshold = 0.0650, connected components = 40
# Threshold = 0.0651, connected components = 40
# Threshold = 0.0652, connected components = 40
# Threshold = 0.0652, connected components = 40
# Threshold = 0.0653, connected components = 40
# Threshold = 0.0654, connected components = 40
# Threshold = 0.0655, connected components = 40
# Threshold = 0.0656, connected components = 40
# Threshold = 0.0657, connected components = 40
# Threshold = 0.0658, connected components = 41
# Threshold = 0.0659, connected components = 41
# Threshold = 0.0659, connected components = 41
# Threshold = 0.0660, connected components = 41
# Threshold = 0.0661, connected components = 41
# Threshold = 0.0662, connected components = 41
# Threshold = 0.0663, connected components = 41
# Threshold = 0.0664, connected components = 41
# Threshold = 0.0665, connected components = 41
# Threshold = 0.0666, connected components = 41
# Threshold = 0.0666, connected components = 41
# Threshold = 0.0667, connected components = 41
# Threshold = 0.0668, connected components = 41
# Threshold = 0.0669, connected components = 41
# Threshold = 0.0670, connected components = 41
# Threshold = 0.0671, connected components = 41
# Threshold = 0.0672, connected components = 41
# Threshold = 0.0673, connected components = 41
# Threshold = 0.0674, connected components = 41
# Threshold = 0.0674, connected components = 41
# Threshold = 0.0675, connected components = 41
# Threshold = 0.0676, connected components = 41
# Threshold = 0.0677, connected components = 41
# Threshold = 0.0678, connected components = 41
# Threshold = 0.0679, connected components = 41
# Threshold = 0.0680, connected components = 41
# Threshold = 0.0681, connected components = 41
# Threshold = 0.0681, connected components = 41
# Threshold = 0.0682, connected components = 41
# Threshold = 0.0683, connected components = 41
# Threshold = 0.0684, connected components = 41
# Threshold = 0.0685, connected components = 41
# Threshold = 0.0686, connected components = 41
# Threshold = 0.0687, connected components = 41
# Threshold = 0.0688, connected components = 41
# Threshold = 0.0688, connected components = 41
# Threshold = 0.0689, connected components = 41
# Threshold = 0.0690, connected components = 41
# Threshold = 0.0691, connected components = 41
# Threshold = 0.0692, connected components = 41
# Threshold = 0.0693, connected components = 41
# Threshold = 0.0694, connected components = 41
# Threshold = 0.0695, connected components = 41
# Threshold = 0.0696, connected components = 41
# Threshold = 0.0696, connected components = 41
# Threshold = 0.0697, connected components = 42
# Threshold = 0.0698, connected components = 42
# Threshold = 0.0699, connected components = 42
# Threshold = 0.0700, connected components = 42
# Threshold = 0.0701, connected components = 42
# Threshold = 0.0702, connected components = 42
# Threshold = 0.0703, connected components = 42
# Threshold = 0.0703, connected components = 42
# Threshold = 0.0704, connected components = 42
# Threshold = 0.0705, connected components = 42
# Threshold = 0.0706, connected components = 42
# Threshold = 0.0707, connected components = 43
# Threshold = 0.0708, connected components = 43
# Threshold = 0.0709, connected components = 43
# Threshold = 0.0710, connected components = 43
# Threshold = 0.0710, connected components = 43
# Threshold = 0.0711, connected components = 43
# Threshold = 0.0712, connected components = 43
# Threshold = 0.0713, connected components = 43
# Threshold = 0.0714, connected components = 43
# Threshold = 0.0715, connected components = 43
# Threshold = 0.0716, connected components = 43
# Threshold = 0.0717, connected components = 43
# Threshold = 0.0718, connected components = 43
# Threshold = 0.0718, connected components = 43
# Threshold = 0.0719, connected components = 43
# Threshold = 0.0720, connected components = 43
# Threshold = 0.0721, connected components = 43
# Threshold = 0.0722, connected components = 43
# Threshold = 0.0723, connected components = 43
# Threshold = 0.0724, connected components = 43
# Threshold = 0.0725, connected components = 44
# Threshold = 0.0725, connected components = 44
# Threshold = 0.0726, connected components = 44
# Threshold = 0.0727, connected components = 44
# Threshold = 0.0728, connected components = 44
# Threshold = 0.0729, connected components = 44
# Threshold = 0.0730, connected components = 44
# Threshold = 0.0731, connected components = 45
# Threshold = 0.0732, connected components = 45
# Threshold = 0.0733, connected components = 45
# Threshold = 0.0733, connected components = 45
# Threshold = 0.0734, connected components = 45
# Threshold = 0.0735, connected components = 45
# Threshold = 0.0736, connected components = 45
# Threshold = 0.0737, connected components = 45
# Threshold = 0.0738, connected components = 45
# Threshold = 0.0739, connected components = 45
# Threshold = 0.0740, connected components = 45
# Threshold = 0.0740, connected components = 45
# Threshold = 0.0741, connected components = 45
# Threshold = 0.0742, connected components = 45
# Threshold = 0.0743, connected components = 45
# Threshold = 0.0744, connected components = 45
# Threshold = 0.0745, connected components = 45
# Threshold = 0.0746, connected components = 45
# Threshold = 0.0747, connected components = 45
# Threshold = 0.0747, connected components = 45
# Threshold = 0.0748, connected components = 45
# Threshold = 0.0749, connected components = 45
# Threshold = 0.0750, connected components = 45
# Threshold = 0.0751, connected components = 45
# Threshold = 0.0752, connected components = 45
# Threshold = 0.0753, connected components = 45
# Threshold = 0.0754, connected components = 45
# Threshold = 0.0755, connected components = 45
# Threshold = 0.0755, connected components = 45
# Threshold = 0.0756, connected components = 45
# Threshold = 0.0757, connected components = 45
# Threshold = 0.0758, connected components = 45
# Threshold = 0.0759, connected components = 45
# Threshold = 0.0760, connected components = 45
# Threshold = 0.0761, connected components = 45
# Threshold = 0.0762, connected components = 45
# Threshold = 0.0762, connected components = 45
# Threshold = 0.0763, connected components = 45
# Threshold = 0.0764, connected components = 45
# Threshold = 0.0765, connected components = 45
# Threshold = 0.0766, connected components = 45
# Threshold = 0.0767, connected components = 45
# Threshold = 0.0768, connected components = 45
# Threshold = 0.0769, connected components = 45
# Threshold = 0.0769, connected components = 45
# Threshold = 0.0770, connected components = 45
# Threshold = 0.0771, connected components = 45
# Threshold = 0.0772, connected components = 45
# Threshold = 0.0773, connected components = 45
# Threshold = 0.0774, connected components = 45
# Threshold = 0.0775, connected components = 45
# Threshold = 0.0776, connected components = 45
# Threshold = 0.0777, connected components = 45
# Threshold = 0.0777, connected components = 45
# Threshold = 0.0778, connected components = 45
# Threshold = 0.0779, connected components = 45
# Threshold = 0.0780, connected components = 45
# Threshold = 0.0781, connected components = 45
# Threshold = 0.0782, connected components = 45
# Threshold = 0.0783, connected components = 45
# Threshold = 0.0784, connected components = 45
# Threshold = 0.0784, connected components = 45
# Threshold = 0.0785, connected components = 45
# Threshold = 0.0786, connected components = 45
# Threshold = 0.0787, connected components = 45
# Threshold = 0.0788, connected components = 45
# Threshold = 0.0789, connected components = 45
# Threshold = 0.0790, connected components = 45
# Threshold = 0.0791, connected components = 45
# Threshold = 0.0791, connected components = 45
# Threshold = 0.0792, connected components = 45
# Threshold = 0.0793, connected components = 45
# Threshold = 0.0794, connected components = 45
# Threshold = 0.0795, connected components = 45
# Threshold = 0.0796, connected components = 45
# Threshold = 0.0797, connected components = 45
# Threshold = 0.0798, connected components = 45
# Threshold = 0.0799, connected components = 46
# Threshold = 0.0799, connected components = 46
# Threshold = 0.0800, connected components = 46
# Threshold = 0.0801, connected components = 46
# Threshold = 0.0802, connected components = 46
# Threshold = 0.0803, connected components = 46
# Threshold = 0.0804, connected components = 46
# Threshold = 0.0805, connected components = 46
# Threshold = 0.0806, connected components = 46
# Threshold = 0.0806, connected components = 46
# Threshold = 0.0807, connected components = 46
# Threshold = 0.0808, connected components = 46
# Threshold = 0.0809, connected components = 46
# Threshold = 0.0810, connected components = 46
# Threshold = 0.0811, connected components = 46
# Threshold = 0.0812, connected components = 46
# Threshold = 0.0813, connected components = 46
# Threshold = 0.0814, connected components = 46
# Threshold = 0.0814, connected components = 46
# Threshold = 0.0815, connected components = 46
# Threshold = 0.0816, connected components = 46
# Threshold = 0.0817, connected components = 46
# Threshold = 0.0818, connected components = 46
# Threshold = 0.0819, connected components = 46
# Threshold = 0.0820, connected components = 46
# Threshold = 0.0821, connected components = 46
# Threshold = 0.0821, connected components = 46
# Threshold = 0.0822, connected components = 46
# Threshold = 0.0823, connected components = 46
# Threshold = 0.0824, connected components = 46
# Threshold = 0.0825, connected components = 46
# Threshold = 0.0826, connected components = 46
# Threshold = 0.0827, connected components = 46
# Threshold = 0.0828, connected components = 46
# Threshold = 0.0828, connected components = 46
# Threshold = 0.0829, connected components = 46
# Threshold = 0.0830, connected components = 46
# Threshold = 0.0831, connected components = 46
# Threshold = 0.0832, connected components = 46
# Threshold = 0.0833, connected components = 46
# Threshold = 0.0834, connected components = 46
# Threshold = 0.0835, connected components = 46
# Threshold = 0.0836, connected components = 46
# Threshold = 0.0836, connected components = 46
# Threshold = 0.0837, connected components = 46
# Threshold = 0.0838, connected components = 46
# Threshold = 0.0839, connected components = 46
# Threshold = 0.0840, connected components = 46
# Threshold = 0.0841, connected components = 46
# Threshold = 0.0842, connected components = 46
# Threshold = 0.0843, connected components = 46
# Threshold = 0.0843, connected components = 46
# Threshold = 0.0844, connected components = 46
# Threshold = 0.0845, connected components = 46
# Threshold = 0.0846, connected components = 46
# Threshold = 0.0847, connected components = 46
# Threshold = 0.0848, connected components = 46
# Threshold = 0.0849, connected components = 46
# Threshold = 0.0850, connected components = 46
# Threshold = 0.0850, connected components = 46
# Threshold = 0.0851, connected components = 46
# Threshold = 0.0852, connected components = 46
# Threshold = 0.0853, connected components = 46
# Threshold = 0.0854, connected components = 46
# Threshold = 0.0855, connected components = 46
# Threshold = 0.0856, connected components = 46
# Threshold = 0.0857, connected components = 46
# Threshold = 0.0858, connected components = 46
# Threshold = 0.0858, connected components = 46
# Threshold = 0.0859, connected components = 46
# Threshold = 0.0860, connected components = 46
# Threshold = 0.0861, connected components = 46
# Threshold = 0.0862, connected components = 46
# Threshold = 0.0863, connected components = 46
# Threshold = 0.0864, connected components = 46
# Threshold = 0.0865, connected components = 46
# Threshold = 0.0865, connected components = 46
# Threshold = 0.0866, connected components = 46
# Threshold = 0.0867, connected components = 46
# Threshold = 0.0868, connected components = 46
# Threshold = 0.0869, connected components = 46
# Threshold = 0.0870, connected components = 46
# Threshold = 0.0871, connected components = 46
# Threshold = 0.0872, connected components = 46
# Threshold = 0.0872, connected components = 46
# Threshold = 0.0873, connected components = 46
# Threshold = 0.0874, connected components = 46
# Threshold = 0.0875, connected components = 46
# Threshold = 0.0876, connected components = 46
# Threshold = 0.0877, connected components = 46
# Threshold = 0.0878, connected components = 46
# Threshold = 0.0879, connected components = 46
# Threshold = 0.0880, connected components = 46
# Threshold = 0.0880, connected components = 46
# Threshold = 0.0881, connected components = 46
# Threshold = 0.0882, connected components = 46
# Threshold = 0.0883, connected components = 46
# Threshold = 0.0884, connected components = 46
# Threshold = 0.0885, connected components = 46
# Threshold = 0.0886, connected components = 46
# Threshold = 0.0887, connected components = 46
# Threshold = 0.0887, connected components = 46
# Threshold = 0.0888, connected components = 46
# Threshold = 0.0889, connected components = 46
# Threshold = 0.0890, connected components = 46
# Threshold = 0.0891, connected components = 46
# Threshold = 0.0892, connected components = 46
# Threshold = 0.0893, connected components = 46
# Threshold = 0.0894, connected components = 46
# Threshold = 0.0895, connected components = 46
# Threshold = 0.0895, connected components = 46
# Threshold = 0.0896, connected components = 46
# Threshold = 0.0897, connected components = 46
# Threshold = 0.0898, connected components = 46
# Threshold = 0.0899, connected components = 46
# Threshold = 0.0900, connected components = 46
# Threshold = 0.0901, connected components = 46
# Threshold = 0.0902, connected components = 46
# Threshold = 0.0902, connected components = 46
# Threshold = 0.0903, connected components = 46
# Threshold = 0.0904, connected components = 46
# Threshold = 0.0905, connected components = 46
# Threshold = 0.0906, connected components = 46
# Threshold = 0.0907, connected components = 46
# Threshold = 0.0908, connected components = 46
# Threshold = 0.0909, connected components = 46
# Threshold = 0.0909, connected components = 47
# Threshold = 0.0910, connected components = 47
# Threshold = 0.0911, connected components = 47
# Threshold = 0.0912, connected components = 47
# Threshold = 0.0913, connected components = 47
# Threshold = 0.0914, connected components = 47
# Threshold = 0.0915, connected components = 47
# Threshold = 0.0916, connected components = 47
# Threshold = 0.0917, connected components = 47
# Threshold = 0.0917, connected components = 47
# Threshold = 0.0918, connected components = 47
# Threshold = 0.0919, connected components = 47
# Threshold = 0.0920, connected components = 47
# Threshold = 0.0921, connected components = 47
# ...
# Threshold = 0.1455, connected components = 51
# Threshold = 0.1456, connected components = 51
# Threshold = 0.1457, connected components = 51
# Threshold = 0.1458, connected components = 51
# Threshold = 0.1459, connected components = 51
# Threshold = 0.1460, connected components = 51
# Threshold = 0.1461, connected components = 51
# Threshold = 0.1461, connected components = 51
# Threshold = 0.1462, connected components = 51
# Threshold = 0.1463, connected components = 51
# Threshold = 0.1464, connected components = 51
# Threshold = 0.1465, connected components = 51
# Threshold = 0.1466, connected components = 51
# Threshold = 0.1467, connected components = 51
# Threshold = 0.1468, connected components = 51
# Threshold = 0.1469, connected components = 51
# Threshold = 0.1469, connected components = 51
# Threshold = 0.1470, connected components = 51
# Threshold = 0.1471, connected components = 51
# Threshold = 0.1472, connected components = 51
# Threshold = 0.1473, connected components = 51
# Threshold = 0.1474, connected components = 51
# Threshold = 0.1475, connected components = 51
# Threshold = 0.1476, connected components = 51
# Threshold = 0.1476, connected components = 51
# Threshold = 0.1477, connected components = 51
# Threshold = 0.1478, connected components = 51
# Threshold = 0.1479, connected components = 51
# Threshold = 0.1480, connected components = 51
# Threshold = 0.1481, connected components = 51
# Threshold = 0.1482, connected components = 51
# Threshold = 0.1483, connected components = 51
# Threshold = 0.1483, connected components = 51
# Threshold = 0.1484, connected components = 51
# Threshold = 0.1485, connected components = 51
# Threshold = 0.1486, connected components = 51
# Threshold = 0.1487, connected components = 51
# Threshold = 0.1488, connected components = 51
# Threshold = 0.1489, connected components = 51
# Threshold = 0.1490, connected components = 51
# Threshold = 0.1491, connected components = 51
# Threshold = 0.1491, connected components = 51
# Threshold = 0.1492, connected components = 51
# Threshold = 0.1493, connected components = 51
# Threshold = 0.1494, connected components = 51
# Threshold = 0.1495, connected components = 51
# Threshold = 0.1496, connected components = 51
# Threshold = 0.1497, connected components = 51
# Threshold = 0.1498, connected components = 51
# Threshold = 0.1498, connected components = 51
# Threshold = 0.1499, connected components = 51
# Threshold = 0.1500, connected components = 51
# Threshold = 0.1501, connected components = 51
# Threshold = 0.1502, connected components = 51
# Threshold = 0.1503, connected components = 51
# Threshold = 0.1504, connected components = 51
# Threshold = 0.1505, connected components = 51
# Threshold = 0.1506, connected components = 51
# Threshold = 0.1506, connected components = 51
# Threshold = 0.1507, connected components = 51
# Threshold = 0.1508, connected components = 51
# Threshold = 0.1509, connected components = 51
# Threshold = 0.1510, connected components = 51
# Threshold = 0.1511, connected components = 51
# Threshold = 0.1512, connected components = 51
# Threshold = 0.1513, connected components = 51
# Threshold = 0.1513, connected components = 51
# Threshold = 0.1514, connected components = 51
# Threshold = 0.1515, connected components = 51
# Threshold = 0.1516, connected components = 51
# Threshold = 0.1517, connected components = 51
# Threshold = 0.1518, connected components = 51
# Threshold = 0.1519, connected components = 51
# Threshold = 0.1520, connected components = 51
# Threshold = 0.1520, connected components = 51
# Threshold = 0.1521, connected components = 51
# Threshold = 0.1522, connected components = 51
# Threshold = 0.1523, connected components = 51
# Threshold = 0.1524, connected components = 51
# Threshold = 0.1525, connected components = 51
# Threshold = 0.1526, connected components = 51
# Threshold = 0.1527, connected components = 51
# Threshold = 0.1528, connected components = 51
# Threshold = 0.1528, connected components = 51
# Threshold = 0.1529, connected components = 51
# Threshold = 0.1530, connected components = 51
# Threshold = 0.1531, connected components = 51
# Threshold = 0.1532, connected components = 51
# Threshold = 0.1533, connected components = 51
# Threshold = 0.1534, connected components = 51
# Threshold = 0.1535, connected components = 51
# Threshold = 0.1535, connected components = 51
# Threshold = 0.1536, connected components = 51
# Threshold = 0.1537, connected components = 51
# Threshold = 0.1538, connected components = 51
# Threshold = 0.1539, connected components = 51
# Threshold = 0.1540, connected components = 51
# Threshold = 0.1541, connected components = 51
# Threshold = 0.1542, connected components = 51
# Threshold = 0.1542, connected components = 51
# Threshold = 0.1543, connected components = 51
# Threshold = 0.1544, connected components = 51
# Threshold = 0.1545, connected components = 51
# Threshold = 0.1546, connected components = 51
# Threshold = 0.1547, connected components = 51
# Threshold = 0.1548, connected components = 51
# Threshold = 0.1549, connected components = 51
# Threshold = 0.1550, connected components = 51
# Threshold = 0.1550, connected components = 51
# Threshold = 0.1551, connected components = 51
# Threshold = 0.1552, connected components = 51
# Threshold = 0.1553, connected components = 51
# Threshold = 0.1554, connected components = 51
# Threshold = 0.1555, connected components = 51
# Threshold = 0.1556, connected components = 51
# Threshold = 0.1557, connected components = 51
# Threshold = 0.1557, connected components = 51
# Threshold = 0.1558, connected components = 51
# Threshold = 0.1559, connected components = 51
# Threshold = 0.1560, connected components = 51
# Threshold = 0.1561, connected components = 51
# Threshold = 0.1562, connected components = 51
# Threshold = 0.1563, connected components = 51
# Threshold = 0.1564, connected components = 51
# Threshold = 0.1564, connected components = 51
# Threshold = 0.1565, connected components = 51
# Threshold = 0.1566, connected components = 51
# Threshold = 0.1567, connected components = 51
# Threshold = 0.1568, connected components = 51
# Threshold = 0.1569, connected components = 51
# Threshold = 0.1570, connected components = 51
# Threshold = 0.1571, connected components = 51
# Threshold = 0.1572, connected components = 51
# Threshold = 0.1572, connected components = 51
# Threshold = 0.1573, connected components = 51
# Threshold = 0.1574, connected components = 51
# Threshold = 0.1575, connected components = 51
# Threshold = 0.1576, connected components = 51
# Threshold = 0.1577, connected components = 51
# Threshold = 0.1578, connected components = 51
# Threshold = 0.1579, connected components = 51
# Threshold = 0.1579, connected components = 51
# Threshold = 0.1580, connected components = 51
# Threshold = 0.1581, connected components = 51
# Threshold = 0.1582, connected components = 51
# Threshold = 0.1583, connected components = 51
# Threshold = 0.1584, connected components = 51
# Threshold = 0.1585, connected components = 51
# Threshold = 0.1586, connected components = 51
# Threshold = 0.1587, connected components = 51
# Threshold = 0.1587, connected components = 51
# Threshold = 0.1588, connected components = 51
# Threshold = 0.1589, connected components = 51
# Threshold = 0.1590, connected components = 51
# Threshold = 0.1591, connected components = 51
# Threshold = 0.1592, connected components = 51
# Threshold = 0.1593, connected components = 51
# Threshold = 0.1594, connected components = 51
# Threshold = 0.1594, connected components = 51
# Threshold = 0.1595, connected components = 51
# Threshold = 0.1596, connected components = 51
# Threshold = 0.1597, connected components = 51
# Threshold = 0.1598, connected components = 51
# Threshold = 0.1599, connected components = 51
# Threshold = 0.1600, connected components = 51
# Threshold = 0.1601, connected components = 51
# Threshold = 0.1601, connected components = 51
# Threshold = 0.1602, connected components = 51
# Threshold = 0.1603, connected components = 51
# Threshold = 0.1604, connected components = 51
# Threshold = 0.1605, connected components = 51
# Threshold = 0.1606, connected components = 51
# Threshold = 0.1607, connected components = 51
# Threshold = 0.1608, connected components = 51
# Threshold = 0.1609, connected components = 51
# Threshold = 0.1609, connected components = 51
# Threshold = 0.1610, connected components = 51
# Threshold = 0.1611, connected components = 51
# Threshold = 0.1612, connected components = 51
# Threshold = 0.1613, connected components = 51
# Threshold = 0.1614, connected components = 51
# Threshold = 0.1615, connected components = 51
# Threshold = 0.1616, connected components = 51
# Threshold = 0.1616, connected components = 51
# Threshold = 0.1617, connected components = 51
# Threshold = 0.1618, connected components = 51
# Threshold = 0.1619, connected components = 51
# Threshold = 0.1620, connected components = 51
# Threshold = 0.1621, connected components = 51
# Threshold = 0.1622, connected components = 51
# Threshold = 0.1623, connected components = 51
# Threshold = 0.1623, connected components = 51
# Threshold = 0.1624, connected components = 51
# Threshold = 0.1625, connected components = 51
# Threshold = 0.1626, connected components = 51
# Threshold = 0.1627, connected components = 51
# Threshold = 0.1628, connected components = 51
# Threshold = 0.1629, connected components = 51
# Threshold = 0.1630, connected components = 51
# Threshold = 0.1631, connected components = 51
# Threshold = 0.1631, connected components = 51
# Threshold = 0.1632, connected components = 51
# Threshold = 0.1633, connected components = 51
# Threshold = 0.1634, connected components = 51
# Threshold = 0.1635, connected components = 51
# Threshold = 0.1636, connected components = 51
# Threshold = 0.1637, connected components = 51
# Threshold = 0.1638, connected components = 51
# Threshold = 0.1638, connected components = 51
# Threshold = 0.1639, connected components = 51
# Threshold = 0.1640, connected components = 51
# Threshold = 0.1641, connected components = 51
# Threshold = 0.1642, connected components = 51
# Threshold = 0.1643, connected components = 51
# Threshold = 0.1644, connected components = 51
# Threshold = 0.1645, connected components = 51
# Threshold = 0.1645, connected components = 51
# Threshold = 0.1646, connected components = 51
# Threshold = 0.1647, connected components = 51
# Threshold = 0.1648, connected components = 51
# Threshold = 0.1649, connected components = 51
# Threshold = 0.1650, connected components = 51
# Threshold = 0.1651, connected components = 51
# Threshold = 0.1652, connected components = 51
# Threshold = 0.1653, connected components = 51
# Threshold = 0.1653, connected components = 51
# Threshold = 0.1654, connected components = 51
# Threshold = 0.1655, connected components = 51
# Threshold = 0.1656, connected components = 51
# Threshold = 0.1657, connected components = 51
# Threshold = 0.1658, connected components = 51
# Threshold = 0.1659, connected components = 51
# Threshold = 0.1660, connected components = 51
# Threshold = 0.1660, connected components = 51
# Threshold = 0.1661, connected components = 51
# Threshold = 0.1662, connected components = 51
# Threshold = 0.1663, connected components = 51
# Threshold = 0.1664, connected components = 51
# Threshold = 0.1665, connected components = 51
# Threshold = 0.1666, connected components = 51
# Threshold = 0.1667, connected components = 51
# Threshold = 0.1668, connected components = 51
# Threshold = 0.1668, connected components = 51
# Threshold = 0.1669, connected components = 51
# Threshold = 0.1670, connected components = 51
# Threshold = 0.1671, connected components = 51
# Threshold = 0.1672, connected components = 51
# Threshold = 0.1673, connected components = 51
# Threshold = 0.1674, connected components = 51
# Threshold = 0.1675, connected components = 51
# Threshold = 0.1675, connected components = 51
# Threshold = 0.1676, connected components = 51
# Threshold = 0.1677, connected components = 51
# Threshold = 0.1678, connected components = 51
# Threshold = 0.1679, connected components = 51
# Threshold = 0.1680, connected components = 51
# Threshold = 0.1681, connected components = 51
# Threshold = 0.1682, connected components = 51
# Threshold = 0.1682, connected components = 51
# Threshold = 0.1683, connected components = 51
# Threshold = 0.1684, connected components = 51
# Threshold = 0.1685, connected components = 51
# Threshold = 0.1686, connected components = 51
# Threshold = 0.1687, connected components = 51
# Threshold = 0.1688, connected components = 51
# Threshold = 0.1689, connected components = 51
# Threshold = 0.1690, connected components = 51
# Threshold = 0.1690, connected components = 51
# Threshold = 0.1691, connected components = 51
# Threshold = 0.1692, connected components = 51
# Threshold = 0.1693, connected components = 51
# Threshold = 0.1694, connected components = 51
# Threshold = 0.1695, connected components = 51
# Threshold = 0.1696, connected components = 51
# Threshold = 0.1697, connected components = 51
# Threshold = 0.1697, connected components = 51
# Threshold = 0.1698, connected components = 51
# Threshold = 0.1699, connected components = 51
# Threshold = 0.1700, connected components = 51
# Threshold = 0.1701, connected components = 51
# Threshold = 0.1702, connected components = 51
# Threshold = 0.1703, connected components = 51
# Threshold = 0.1704, connected components = 51
# Threshold = 0.1704, connected components = 51
# Threshold = 0.1705, connected components = 51
# Threshold = 0.1706, connected components = 51
# Threshold = 0.1707, connected components = 51
# Threshold = 0.1708, connected components = 51
# Threshold = 0.1709, connected components = 51
# Threshold = 0.1710, connected components = 51
# Threshold = 0.1711, connected components = 51
# Threshold = 0.1712, connected components = 51
# Threshold = 0.1712, connected components = 51
# Threshold = 0.1713, connected components = 51
# Threshold = 0.1714, connected components = 51
# Threshold = 0.1715, connected components = 51
# Threshold = 0.1716, connected components = 51
# Threshold = 0.1717, connected components = 51
# Threshold = 0.1718, connected components = 51
# Threshold = 0.1719, connected components = 51
# Threshold = 0.1719, connected components = 51
# Threshold = 0.1720, connected components = 51
# Threshold = 0.1721, connected components = 51
# Threshold = 0.1722, connected components = 51
# Threshold = 0.1723, connected components = 51
# Threshold = 0.1724, connected components = 51
# Threshold = 0.1725, connected components = 51
# Threshold = 0.1726, connected components = 51
# Threshold = 0.1726, connected components = 51
# Threshold = 0.1727, connected components = 51
# Threshold = 0.1728, connected components = 51
# Threshold = 0.1729, connected components = 51
# Threshold = 0.1730, connected components = 51
# Threshold = 0.1731, connected components = 51
# Threshold = 0.1732, connected components = 51
# Threshold = 0.1733, connected components = 51
# Threshold = 0.1734, connected components = 51
# Threshold = 0.1734, connected components = 51
# Threshold = 0.1735, connected components = 51
# Threshold = 0.1736, connected components = 51
# Threshold = 0.1737, connected components = 51
# Threshold = 0.1738, connected components = 51
# Threshold = 0.1739, connected components = 51
# Threshold = 0.1740, connected components = 51
# Threshold = 0.1741, connected components = 51
# Threshold = 0.1741, connected components = 51
# Threshold = 0.1742, connected components = 51
# Threshold = 0.1743, connected components = 51
# Threshold = 0.1744, connected components = 51
# Threshold = 0.1745, connected components = 51
# Threshold = 0.1746, connected components = 51
# Threshold = 0.1747, connected components = 51
# Threshold = 0.1748, connected components = 51
# Threshold = 0.1749, connected components = 51
# Threshold = 0.1749, connected components = 51
# Threshold = 0.1750, connected components = 51
# Threshold = 0.1751, connected components = 51
# Threshold = 0.1752, connected components = 51
# Threshold = 0.1753, connected components = 51
# Threshold = 0.1754, connected components = 51
# Threshold = 0.1755, connected components = 51
# Threshold = 0.1756, connected components = 51
# Threshold = 0.1756, connected components = 51
# Threshold = 0.1757, connected components = 51
# Threshold = 0.1758, connected components = 51
# Threshold = 0.1759, connected components = 51
# Threshold = 0.1760, connected components = 52

# %%
import networkx as nx

# %%
threshold_mask = np.abs(M) > theta_star
# this is the adjacency matrix that we are going to use for our analysis
A_star = threshold_mask.astype(int)

# %% [markdown]
# Analyze the structural properties of W * (degree distribution, diameter, clustering, degree assortativity, betweeness centrality). In what respect, if any, the graph is different from a random ER graph?

# %%
K = A_star.sum(axis = 0)
print("Mean degree: %.2f"% K.mean())
print("Degree standard deviation: %.2f"% K.std())
# not having much elements for a graphs we prefer to use a small amount of bins 
# in order to capture less information but more reliable
entries, bin_extremes, _ = plt.hist(K, bins = 6, histtype = 'step')
bin_centers = (bin_extremes[1:] + bin_extremes[:-1])/2
plt.errorbar(bin_centers, entries, yerr = np.sqrt(entries), fmt = '.', label = 'entries with \npoisson error')
plt.legend(loc = "upper left")
plt.show()
# Out:
# Mean degree: 30.42
# Degree standard deviation: 10.28

# %% [markdown]
# Using the networkx library we can easily compute most of the quantities of interest.

# %%
G = nx.from_numpy_matrix(A_star)

D = nx.diameter(G)
print("Diameter of the network: ", D)

# local clustering for each node
c_i_dict = nx.clustering(G)
n_nodes = len(G)
c_i = np.zeros(n_nodes)
for i in range(n_nodes):
    c_i[i] = c_i_dict[i]
    
# global clustering
C = c_i.mean()
print("Global clustering coefficient: %.2f"% C)

deg_assortativity = nx.degree_assortativity_coefficient(G)
print("Degree assortativity: %.2f"%deg_assortativity)

btw_centrality = nx.betweenness_centrality(G)
b_c = np.zeros(n_nodes)
for i in range(n_nodes):
    b_c[i] = btw_centrality[i]
print("Max beetweenness centrality: %.2f"%b_c.max())
# Out:
# Diameter of the network:  3
# Global clustering coefficient: 0.73
# Degree assortativity: -0.24
# Max beetweenness centrality: 0.05

# %% [markdown]
# We can compare these results with the one that we would find in an Erdosh-Reny graph with the same number of nodes and with probability of connecting two nodes given by $p = \frac{<k>}{n-1}$, where $<k>$ is the observed average degree of $A^*$. To do this, we consider an ensamble of E-R graphs in order to compute the estimated quantities and not the one of a single realization.

# %%
p = K.mean()/(n_nodes-1)
graphs_number = 100

# we are going to store in the following arrays all the results for each single ER graph 
# and then make a statistic out of them
ER_k_std_devs = np.zeros(graphs_number)
ER_diameters = np.zeros(graphs_number)
ER_cluster_coeffs = np.zeros(graphs_number)
ER_deg_assortativities = np.zeros(graphs_number)
ER_max_btw_centralities = np.zeros(graphs_number)


for i in range(graphs_number):
    # create an Erdosh-Reny graph
    ERG = nx.gnp_random_graph(n_nodes,p)
    # compute the degree standard deviation
    degs_dict = ERG.degree()
    degs = np.zeros(n_nodes)
    for j in range(n_nodes):
        degs[j] = degs_dict[j]
    ER_k_std_devs[i] = degs.std()
    
    ER_diameters[i] =  nx.diameter(ERG)
    
    c_i_dict = nx.clustering(ERG)
    c_i = np.zeros(n_nodes)
    for j in range(n_nodes):
        c_i[j] = c_i_dict[j]

    # global clustering
    ER_cluster_coeffs[i] = c_i.mean()

    ER_deg_assortativities[i] = nx.degree_assortativity_coefficient(ERG)

    btw_centrality = nx.betweenness_centrality(ERG)
    b_c = np.zeros(n_nodes)
    for j in range(n_nodes):
        b_c[j] = btw_centrality[j]
    ER_max_btw_centralities[i] = b_c.max()

print("Degree standard deviation: %.2f"% ER_k_std_devs.mean())
print("Diameter of the network: %.2f" % ER_diameters.mean())
print("Global clustering coefficient: %.2f"% ER_cluster_coeffs.mean())
print("Degree assortativity: %.2f"%ER_deg_assortativities.mean())
print("Max beetweenness centrality: %.2f"%ER_max_btw_centralities.mean())
# Out:
# Degree standard deviation: 3.37
# Diameter of the network: 2.00
# Global clustering coefficient: 0.60
# Degree assortativity: -0.04
# Max beetweenness centrality: 0.01

# %% [markdown]
# Confronting the results of the real network with the ensamble of ER graphs:
#
# | Quantity | Real graph | ER graph|
# | --- | --- | --- |
# | degree std dev | 10.28 | 3.38 |
# | diameter | 3 | 2.00 |
# | clustering | 0.73| 0.59 |
# | assortativity | -0.24 | -0.04 |
# | max centrality | 0.05 | 0.01 |
#
# We can see that none of these quantities is too similar between the two kinds of graphs.
#
# More precisely we can conclude that our network:
# * presents a much higher variance in the degree distribution;
# * has a larger diameter (ER diameter being 2.00 for a hundred graphs imply that none of them has diameter equal 3!);
# * has a higher clustering coefficient;
# * has a disassortative behaviour w.r.t. the almost neutral one of the ER ensamble;
# * has a central node with a betweenness centrality that is 5 times higher than the "central" node of ER graphs.
#
# All this suggests that the network of the species has an underlying structure that is not random, but possibly depends on the "microscopic" details of each species.
#
# NOTE: ER results could vary a bit because we don't have a fixed seed for their generator.
